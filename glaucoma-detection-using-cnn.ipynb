# %% [markdown]
# ### **1. Import the Required Libraries**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### **2. Load the Image Training and Validation Datasets**

# %% [markdown]
# #### **i. Get the Image Dataset Paths**

# %%
train_dataset_path = '/kaggle/input/fundus-pytorch/train'
validation_dataset_path = '/kaggle/input/fundus-pytorch/val'

# %% [markdown]
# #### **ii. Load Image Datasets and Apply Augmentations**

# %% [markdown]
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 224
IMG_HEIGHT = 224
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest',)
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 8621 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 5747 images belonging to 2 classes.

# %% [markdown]
# #### **iii. Get the Label Mappings**

# %% [markdown]
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
label_mapping = {0: "normal", 1: "glaucoma"}
labels = {label_mapping[value]: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# normal : 0
# glaucoma : 1

# %% [markdown]
# ### **3. Plotting Sample Training Images**

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label_index = np.argmax(train_generator[0][1][idx])
        label = list(labels.keys())[label_index]  # Get the key corresponding to the label index
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ### **4. Training a CNN Model**

# %% [markdown]
# Since the training dataset is ready let's create a simple CNN Model to train on the image datasets

# %% [markdown]
# #### **i. Create a CNN Model**

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Flatten(),

        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=128, activation='relu'),
        Dropout(0.5),
        Dense(units=2, activation='sigmoid')
    ])

    return model

# %%
cnn_model = create_model()

# %%
print(cnn_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 220, 220, 128)     9728
#
#  activation (Activation)     (None, 220, 220, 128)     0
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 128)    0
#  )
#
#  batch_normalization (BatchN  (None, 110, 110, 128)    512
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 108, 108, 64)      73792
#
#  activation_1 (Activation)   (None, 108, 108, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 54, 54, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 32)        18464
#
#  activation_2 (Activation)   (None, 52, 52, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 32)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 26, 26, 32)       128
#  hNormalization)
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dense (Dense)               (None, 256)               5538048
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 5,674,082
# Trainable params: 5,673,634
# Non-trainable params: 448
# _________________________________________________________________
# None

# %%
from tensorflow.keras.utils import plot_model
plot_model(cnn_model, expand_nested=True, show_shapes=True, show_layer_names=False)

# %% [markdown]
# #### **ii. Defining Callbacks**

# %% [markdown]
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)

# %% [markdown]
# #### **a. Reduce Learning Rate on Plateau**
#
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %% [markdown]
# #### **iii. Defining the Optimizer**

# %%
optimizer = Adam(learning_rate=0.0001)

# %% [markdown]
# #### **iv. Compile the Model**

# %%
cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# #### **v. Training the Model**

# %%
history = cnn_model.fit(train_generator, epochs=50, validation_data=validation_generator,
                       verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 270/270 - 332s - loss: 1.0057 - accuracy: 0.5785 - val_loss: 0.6556 - val_accuracy: 0.6325 - lr: 1.0000e-04 - 332s/epoch - 1s/step
# Epoch 2/50
# 270/270 - 225s - loss: 0.7513 - accuracy: 0.6087 - val_loss: 0.6423 - val_accuracy: 0.6790 - lr: 1.0000e-04 - 225s/epoch - 833ms/step
# Epoch 3/50
# 270/270 - 224s - loss: 0.7152 - accuracy: 0.6165 - val_loss: 0.6409 - val_accuracy: 0.6435 - lr: 1.0000e-04 - 224s/epoch - 831ms/step
# Epoch 4/50
# 270/270 - 224s - loss: 0.6916 - accuracy: 0.6367 - val_loss: 0.6663 - val_accuracy: 0.6671 - lr: 1.0000e-04 - 224s/epoch - 828ms/step
# Epoch 5/50
# 270/270 - 225s - loss: 0.6911 - accuracy: 0.6346 - val_loss: 0.6250 - val_accuracy: 0.6904 - lr: 1.0000e-04 - 225s/epoch - 834ms/step
# Epoch 6/50
# 270/270 - 228s - loss: 0.6799 - accuracy: 0.6459 - val_loss: 0.6488 - val_accuracy: 0.6664 - lr: 1.0000e-04 - 228s/epoch - 844ms/step
# Epoch 7/50
# 270/270 - 225s - loss: 0.6716 - accuracy: 0.6425 - val_loss: 0.6357 - val_accuracy: 0.6764 - lr: 1.0000e-04 - 225s/epoch - 834ms/step
# Epoch 8/50
# 270/270 - 224s - loss: 0.6719 - accuracy: 0.6433 - val_loss: 0.6427 - val_accuracy: 0.6490 - lr: 1.0000e-04 - 224s/epoch - 830ms/step
# Epoch 9/50
# 270/270 - 225s - loss: 0.6573 - accuracy: 0.6535 - val_loss: 0.6208 - val_accuracy: 0.6922 - lr: 1.0000e-04 - 225s/epoch - 835ms/step
# Epoch 10/50
# 270/270 - 225s - loss: 0.6569 - accuracy: 0.6562 - val_loss: 0.6124 - val_accuracy: 0.6946 - lr: 1.0000e-04 - 225s/epoch - 835ms/step
# Epoch 11/50
# 270/270 - 224s - loss: 0.6485 - accuracy: 0.6667 - val_loss: 0.6199 - val_accuracy: 0.6856 - lr: 1.0000e-04 - 224s/epoch - 828ms/step
# Epoch 12/50
# 270/270 - 223s - loss: 0.6483 - accuracy: 0.6700 - val_loss: 0.6257 - val_accuracy: 0.6797 - lr: 1.0000e-04 - 223s/epoch - 827ms/step
# Epoch 13/50
# 270/270 - 223s - loss: 0.6401 - accuracy: 0.6747 - val_loss: 0.6185 - val_accuracy: 0.6981 - lr: 1.0000e-04 - 223s/epoch - 827ms/step
# Epoch 14/50
# 270/270 - 222s - loss: 0.6425 - accuracy: 0.6778 - val_loss: 0.6034 - val_accuracy: 0.7078 - lr: 1.0000e-04 - 222s/epoch - 821ms/step
# Epoch 15/50
# 270/270 - 225s - loss: 0.6380 - accuracy: 0.6753 - val_loss: 0.6019 - val_accuracy: 0.6965 - lr: 1.0000e-04 - 225s/epoch - 834ms/step
# Epoch 16/50
# 270/270 - 226s - loss: 0.6318 - accuracy: 0.6799 - val_loss: 0.5960 - val_accuracy: 0.7164 - lr: 1.0000e-04 - 226s/epoch - 838ms/step
# Epoch 17/50
# 270/270 - 224s - loss: 0.6388 - accuracy: 0.6843 - val_loss: 0.5838 - val_accuracy: 0.7247 - lr: 1.0000e-04 - 224s/epoch - 829ms/step
# Epoch 18/50
# 270/270 - 225s - loss: 0.6415 - accuracy: 0.6785 - val_loss: 0.5878 - val_accuracy: 0.7249 - lr: 1.0000e-04 - 225s/epoch - 835ms/step
# Epoch 19/50
# 270/270 - 222s - loss: 0.6299 - accuracy: 0.6859 - val_loss: 0.5962 - val_accuracy: 0.7199 - lr: 1.0000e-04 - 222s/epoch - 823ms/step
# Epoch 20/50
# 270/270 - 225s - loss: 0.6290 - accuracy: 0.6825 - val_loss: 0.5775 - val_accuracy: 0.7324 - lr: 1.0000e-04 - 225s/epoch - 833ms/step
# Epoch 21/50
# 270/270 - 224s - loss: 0.6328 - accuracy: 0.6855 - val_loss: 0.5757 - val_accuracy: 0.7353 - lr: 1.0000e-04 - 224s/epoch - 830ms/step
# Epoch 22/50
# 270/270 - 222s - loss: 0.6203 - accuracy: 0.6927 - val_loss: 0.5895 - val_accuracy: 0.7258 - lr: 1.0000e-04 - 222s/epoch - 823ms/step
# Epoch 23/50
# 270/270 - 223s - loss: 0.6153 - accuracy: 0.6948 - val_loss: 0.5687 - val_accuracy: 0.7421 - lr: 1.0000e-04 - 223s/epoch - 824ms/step
# Epoch 24/50
# 270/270 - 225s - loss: 0.6169 - accuracy: 0.6947 - val_loss: 0.5794 - val_accuracy: 0.7306 - lr: 1.0000e-04 - 225s/epoch - 834ms/step
# Epoch 25/50
# 270/270 - 223s - loss: 0.6219 - accuracy: 0.6917 - val_loss: 0.5761 - val_accuracy: 0.7320 - lr: 1.0000e-04 - 223s/epoch - 826ms/step
# Epoch 26/50
# 270/270 - 221s - loss: 0.6087 - accuracy: 0.7011 - val_loss: 0.6102 - val_accuracy: 0.6941 - lr: 1.0000e-04 - 221s/epoch - 819ms/step
# Epoch 27/50
# 270/270 - 221s - loss: 0.6220 - accuracy: 0.6935 - val_loss: 0.5722 - val_accuracy: 0.7461 - lr: 1.0000e-04 - 221s/epoch - 820ms/step
# Epoch 28/50
# 270/270 - 225s - loss: 0.6104 - accuracy: 0.6996 - val_loss: 0.5734 - val_accuracy: 0.7376 - lr: 1.0000e-04 - 225s/epoch - 832ms/step
# Epoch 29/50
# 270/270 - 223s - loss: 0.6001 - accuracy: 0.7064 - val_loss: 0.5593 - val_accuracy: 0.7524 - lr: 3.1623e-05 - 223s/epoch - 825ms/step
# Epoch 30/50
# 270/270 - 222s - loss: 0.6002 - accuracy: 0.7064 - val_loss: 0.5601 - val_accuracy: 0.7491 - lr: 3.1623e-05 - 222s/epoch - 824ms/step
# Epoch 31/50
# 270/270 - 222s - loss: 0.6025 - accuracy: 0.7076 - val_loss: 0.5567 - val_accuracy: 0.7545 - lr: 3.1623e-05 - 222s/epoch - 823ms/step
# Epoch 32/50
# 270/270 - 223s - loss: 0.5926 - accuracy: 0.7122 - val_loss: 0.5568 - val_accuracy: 0.7538 - lr: 3.1623e-05 - 223s/epoch - 827ms/step
# Epoch 33/50
# 270/270 - 222s - loss: 0.5917 - accuracy: 0.7114 - val_loss: 0.5586 - val_accuracy: 0.7519 - lr: 3.1623e-05 - 222s/epoch - 822ms/step
# Epoch 34/50
# 270/270 - 223s - loss: 0.5940 - accuracy: 0.7140 - val_loss: 0.5634 - val_accuracy: 0.7467 - lr: 3.1623e-05 - 223s/epoch - 826ms/step
# Epoch 35/50
# 270/270 - 226s - loss: 0.5908 - accuracy: 0.7157 - val_loss: 0.5681 - val_accuracy: 0.7428 - lr: 3.1623e-05 - 226s/epoch - 836ms/step
# Epoch 36/50
# 270/270 - 222s - loss: 0.5909 - accuracy: 0.7159 - val_loss: 0.5611 - val_accuracy: 0.7491 - lr: 3.1623e-05 - 222s/epoch - 822ms/step
# Epoch 37/50
# 270/270 - 225s - loss: 0.5814 - accuracy: 0.7157 - val_loss: 0.5556 - val_accuracy: 0.7536 - lr: 1.0000e-05 - 225s/epoch - 832ms/step
# Epoch 38/50
# 270/270 - 223s - loss: 0.5938 - accuracy: 0.7121 - val_loss: 0.5616 - val_accuracy: 0.7479 - lr: 1.0000e-05 - 223s/epoch - 827ms/step
# Epoch 39/50
# 270/270 - 224s - loss: 0.5825 - accuracy: 0.7244 - val_loss: 0.5598 - val_accuracy: 0.7507 - lr: 1.0000e-05 - 224s/epoch - 830ms/step
# Epoch 40/50
# 270/270 - 224s - loss: 0.5831 - accuracy: 0.7207 - val_loss: 0.5506 - val_accuracy: 0.7543 - lr: 1.0000e-05 - 224s/epoch - 830ms/step
# Epoch 41/50
# 270/270 - 222s - loss: 0.5877 - accuracy: 0.7143 - val_loss: 0.5564 - val_accuracy: 0.7533 - lr: 1.0000e-05 - 222s/epoch - 823ms/step
# Epoch 42/50
# 270/270 - 223s - loss: 0.5842 - accuracy: 0.7177 - val_loss: 0.5543 - val_accuracy: 0.7560 - lr: 1.0000e-05 - 223s/epoch - 825ms/step
# Epoch 43/50
# 270/270 - 223s - loss: 0.5816 - accuracy: 0.7200 - val_loss: 0.5531 - val_accuracy: 0.7580 - lr: 1.0000e-05 - 223s/epoch - 826ms/step
# Epoch 44/50
# 270/270 - 223s - loss: 0.5842 - accuracy: 0.7216 - val_loss: 0.5559 - val_accuracy: 0.7534 - lr: 1.0000e-05 - 223s/epoch - 826ms/step
# Epoch 45/50
# 270/270 - 223s - loss: 0.5816 - accuracy: 0.7235 - val_loss: 0.5554 - val_accuracy: 0.7560 - lr: 1.0000e-05 - 223s/epoch - 828ms/step
# Epoch 46/50
# 270/270 - 222s - loss: 0.5760 - accuracy: 0.7228 - val_loss: 0.5559 - val_accuracy: 0.7552 - lr: 3.1623e-06 - 222s/epoch - 824ms/step
# Epoch 47/50
# 270/270 - 223s - loss: 0.5826 - accuracy: 0.7223 - val_loss: 0.5568 - val_accuracy: 0.7552 - lr: 3.1623e-06 - 223s/epoch - 825ms/step
# Epoch 48/50
# 270/270 - 221s - loss: 0.5776 - accuracy: 0.7227 - val_loss: 0.5547 - val_accuracy: 0.7557 - lr: 3.1623e-06 - 221s/epoch - 819ms/step
# Epoch 49/50
# 270/270 - 224s - loss: 0.5768 - accuracy: 0.7216 - val_loss: 0.5546 - val_accuracy: 0.7555 - lr: 3.1623e-06 - 224s/epoch - 831ms/step
# Epoch 50/50
# 270/270 - 222s - loss: 0.5794 - accuracy: 0.7229 - val_loss: 0.5532 - val_accuracy: 0.7566 - lr: 3.1623e-06 - 222s/epoch - 824ms/step

# %% [markdown]
# ### **5. Plotting the Model Metrics**

# %% [markdown]
# #### **i. Plotting training and validation accuracy, loss and learning rate**

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **6. Testing the Model on Test Set**

# %% [markdown]
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/kaggle/input/fundus-pytorch/test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 2874 images belonging to 2 classes.

# %% [markdown]
# ### **7. Model Prediction on the Test Dataset**

# %%
predictions = cnn_model.predict(test_generator)
# Out:
# 90/90 [==============================] - 44s 487ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = np.argmax(predictions[idx])
        label = list(labels.keys())[predicted_label]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 90/90 [==============================] - 29s 320ms/step - loss: 0.5531 - accuracy: 0.7568

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.5531222224235535
# Test Accuracy: 0.756784975528717

# %% [markdown]
# The test loss and test accuracy is the same as validation loss and validation accuracy at the last step since the testing and validation datasets are same.

# %% [markdown]
# ### **8. Plotting the Classification Metrics**

# %% [markdown]
# ### **i. Confusion Matrix**

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.97      0.83      1754
#            1       0.89      0.43      0.58      1120
#
#     accuracy                           0.76      2874
#    macro avg       0.81      0.70      0.70      2874
# weighted avg       0.79      0.76      0.73      2874
